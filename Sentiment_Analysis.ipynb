# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from transformers) (3.16.1)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Using cached huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.11.6-cp38-cp38-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.3-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/eecs738/lib/python3.8/site-packages (from requests->transformers) (2024.8.30)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 18.2 MB/s eta 0:00:0000:010:01
# Using cached huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading regex-2024.11.6-cp38-cp38-macosx_11_0_arm64.whl (284 kB)
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading tokenizers-0.20.3-cp38-cp38-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 16.7 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.30.2 regex-2024.11.6 safetensors-0.5.3 tokenizers-0.20.3 transformers-4.46.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

#--------------------------------------------------------------------------------------
# results = []

# # Load your CSV
# df = pd.read_csv("filtered_dataset.csv")  # replace with your filename

# # Create the sentiment analysis pipeline
# pipe = pipeline(
#     "sentiment-analysis",
#     model="StephanAkkerman/FinTwitBERT-sentiment",
#     device=0 
# )

# # Pass each tweet into the pipeline
# tweets = df['tweet'].dropna().tolist() 

# for tweet in tweets:
#     result = pipe(tweet)
#     label = result[0]['label']
#     score = result[0]['score']
#     results.append((tweet, label, score))

# # Create a DataFrame
# results_df = pd.DataFrame(results, columns=["tweet", "predicted_label", "confidence_score"])

# # Save it
# results_df.to_csv("predicted_tweet_sentiments.csv", index=False)
#------------------------------------------------------------------------------------------

actual_df = pd.read_csv("filtered_dataset.csv")
predicted_df = pd.read_csv("predicted_tweet_sentiments.csv")

merged_df = pd.merge(actual_df, predicted_df, on="tweet")

del actual_df, predicted_df

# Map predicted text labels (BEARISH, BULLISH, NEUTRAL) to numbers
def map_predicted(label):
    if label.upper() == "BULLISH":
        return 0
    elif label.upper() == "NEUTRAL":
        return 1
    elif label.upper() == "BEARISH":
        return 2
    else:
        return -1

merged_df['predicted_mapped'] = merged_df['predicted_label'].apply(map_predicted)

# Add a "Correct" column
merged_df['correct'] = merged_df['sentiment'] == merged_df['predicted_mapped']

merged_df.to_csv("comparison_results.csv", index=False)

# Calculate Accuracy
accuracy = accuracy_score(merged_df['sentiment'], merged_df['predicted_mapped'])
print(f"Accuracy: {accuracy*100:.2f}%")

cm = confusion_matrix(merged_df['sentiment'], merged_df['predicted_mapped'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Positive", "Neutral", "Negative"])
disp.plot(cmap="Blues")
